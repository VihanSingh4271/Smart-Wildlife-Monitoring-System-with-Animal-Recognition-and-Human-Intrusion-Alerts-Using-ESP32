# %%
import cv2
from playsound import playsound  # Cross-platform sound playback library
from ultralytics import YOLO
import threading

# %%
# Load the trained YOLO model
model = YOLO('/Users/ishanrawat/VihanProject/AnimalProject/best.pt')

# %%
cap = cv2.VideoCapture(0)  # Use 0 for the default camera, or change to the appropriate camera index
if not cap.isOpened():
    print("Error: Unable to access the camera.")
    exit()

# %%
# Get camera properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = int(cap.get(cv2.CAP_PROP_FPS))
print(f"Camera resolution: {width}x{height}, FPS: {fps}")
# Out:
# Camera resolution: 1920x1080, FPS: 30

# %%
# Function to play the alarm sound
def play_alarm():
    try:
        print("Playing alarm sound...")
        playsound('/Users/ishanrawat/VihanProject/AnimalProject/alert.mp3')  # Replace with the path to your alarm sound file
    except Exception as e:
        print(f"Error playing sound: {e}")

# %%
# Real-time detection loop
try:
    while True:
        ret, frame = cap.read()
        if not ret:
            print("Error: Unable to read from camera.")
            break

        # YOLO inference
        results = model.predict(frame, imgsz=640, conf=0.5, device="cpu")
        annotated_frame = results[0].plot()

        # Print detected classes for debugging
        detected_classes = results[0].names
        print(f"Detected classes: {detected_classes}")

        # Iterate through detections and check if 'human' is detected
        human_detected = False
        for result in results[0].boxes:  # Iterate through detected objects
            detected_label = detected_classes[int(result.cls)]
            print(f"Detected label: {detected_label}")  # Print the detected class label for debugging
            
            # Check if the detected label contains "human" (case-insensitive)
            if "human" in detected_label.lower():
                human_detected = True
                break

        # Trigger alarm if human is detected
        if human_detected:
            print("Human detected! Triggering alarm...")
            alarm_thread = threading.Thread(target=play_alarm)
            alarm_thread.start()

        # Display the annotated frame
        cv2.imshow('Real-Time Detection', annotated_frame)

        # Exit when 'q' is pressed
        if cv2.waitKey(1) & 0xFF == ord('q'):
            print("Exiting real-time detection...")
            break

except Exception as e:
    print(f"An error occurred: {e}")

# Release resources
finally:
    cap.release()
    cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 Human, 67.9ms
# Speed: 11.8ms preprocess, 67.9ms inference, 10.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 52.1ms
# Speed: 1.7ms preprocess, 52.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 101.2ms
# Speed: 1.4ms preprocess, 101.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 51.3ms
# Speed: 1.6ms preprocess, 51.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 55.2ms
# Speed: 1.6ms preprocess, 55.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 51.5ms
# Speed: 1.3ms preprocess, 51.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 44.8ms
# Speed: 1.2ms preprocess, 44.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 37.5ms
# Speed: 1.4ms preprocess, 37.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 41.0ms
# Speed: 1.6ms preprocess, 41.0ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 47.8ms
# Speed: 1.5ms preprocess, 47.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 57.5ms
# Speed: 1.4ms preprocess, 57.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 55.3ms
# Speed: 1.7ms preprocess, 55.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 46.4ms
# Speed: 1.7ms preprocess, 46.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 38.1ms
# Speed: 1.7ms preprocess, 38.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Nothing Found, 36.8ms
# Speed: 1.2ms preprocess, 36.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Nothing Found
#
# 0: 384x640 1 Human, 36.3ms
# Speed: 1.7ms preprocess, 36.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 1 Human, 40.3ms
# Speed: 1.5ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 (no detections), 35.9ms
# Speed: 1.4ms preprocess, 35.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 1 Human, 35.6ms
# Speed: 1.4ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: Human
# Human detected! Triggering alarm...
# Playing alarm sound...
#
# 0: 384x640 (no detections), 37.9ms
# Speed: 1.4ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.1ms
# Speed: 1.5ms preprocess, 37.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 151.6ms
# Speed: 1.6ms preprocess, 151.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 1.3ms preprocess, 40.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.9ms
# Speed: 1.8ms preprocess, 38.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 1 giraffe, 35.9ms
# Speed: 1.7ms preprocess, 35.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: giraffe
#
# 0: 384x640 1 giraffe, 34.8ms
# Speed: 1.7ms preprocess, 34.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: giraffe
#
# 0: 384x640 1 giraffe, 38.9ms
# Speed: 1.6ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: giraffe
#
# 0: 384x640 (no detections), 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 1 giraffe, 51.4ms
# Speed: 1.7ms preprocess, 51.4ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: giraffe
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.4ms preprocess, 40.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 1 giraffe, 47.8ms
# Speed: 1.6ms preprocess, 47.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
# Detected label: giraffe
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 1.5ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 65.1ms
# Speed: 1.7ms preprocess, 65.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 1.9ms preprocess, 39.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 43.5ms
# Speed: 1.8ms preprocess, 43.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 41.2ms
# Speed: 2.0ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.7ms
# Speed: 1.7ms preprocess, 37.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.4ms
# Speed: 1.8ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.2ms
# Speed: 1.6ms preprocess, 38.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.0ms
# Speed: 1.6ms preprocess, 37.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 35.6ms
# Speed: 1.3ms preprocess, 35.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 36.0ms
# Speed: 1.5ms preprocess, 36.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 36.1ms
# Speed: 1.3ms preprocess, 36.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 47.2ms
# Speed: 1.5ms preprocess, 47.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 39.4ms
# Speed: 2.0ms preprocess, 39.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.4ms preprocess, 45.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 41.9ms
# Speed: 1.7ms preprocess, 41.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 44.2ms
# Speed: 1.4ms preprocess, 44.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 50.4ms
# Speed: 1.8ms preprocess, 50.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 36.4ms
# Speed: 1.5ms preprocess, 36.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.2ms
# Speed: 1.4ms preprocess, 37.2ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 1.4ms preprocess, 40.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 35.8ms
# Speed: 1.5ms preprocess, 35.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.5ms preprocess, 35.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 36.4ms
# Speed: 1.5ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 42.5ms
# Speed: 1.9ms preprocess, 42.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 36.9ms
# Speed: 1.4ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.6ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 44.6ms
# Speed: 1.7ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 44.9ms
# Speed: 1.5ms preprocess, 44.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 42.7ms
# Speed: 2.0ms preprocess, 42.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.5ms
# Speed: 2.0ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 42.1ms
# Speed: 1.7ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.5ms preprocess, 41.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 46.3ms
# Speed: 5.4ms preprocess, 46.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 41.1ms
# Speed: 1.6ms preprocess, 41.1ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.4ms preprocess, 54.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 49.2ms
# Speed: 1.8ms preprocess, 49.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 62.4ms
# Speed: 1.5ms preprocess, 62.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 104.1ms
# Speed: 3.9ms preprocess, 104.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 70.3ms
# Speed: 1.8ms preprocess, 70.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 48.4ms
# Speed: 1.6ms preprocess, 48.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 1.6ms preprocess, 54.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 36.3ms
# Speed: 7.7ms preprocess, 36.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 50.8ms
# Speed: 1.6ms preprocess, 50.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 47.6ms
# Speed: 1.5ms preprocess, 47.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 44.6ms
# Speed: 1.4ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 93.6ms
# Speed: 9.7ms preprocess, 93.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 59.4ms
# Speed: 1.7ms preprocess, 59.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 47.9ms
# Speed: 1.8ms preprocess, 47.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 64.1ms
# Speed: 1.7ms preprocess, 64.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 48.1ms
# Speed: 1.5ms preprocess, 48.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 48.0ms
# Speed: 1.8ms preprocess, 48.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 45.4ms
# Speed: 1.8ms preprocess, 45.4ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.8ms
# Speed: 1.8ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.9ms preprocess, 40.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 47.8ms
# Speed: 2.1ms preprocess, 47.8ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 1.5ms preprocess, 53.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.2ms
# Speed: 1.6ms preprocess, 40.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 137.0ms
# Speed: 2.2ms preprocess, 137.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 244.0ms
# Speed: 2.1ms preprocess, 244.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 36.6ms
# Speed: 1.7ms preprocess, 36.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 35.5ms
# Speed: 1.9ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 1.7ms preprocess, 40.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 36.8ms
# Speed: 1.6ms preprocess, 36.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.7ms
# Speed: 1.4ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# ...
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 1.6ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.3ms
# Speed: 1.7ms preprocess, 37.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 39.8ms
# Speed: 1.9ms preprocess, 39.8ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.1ms
# Speed: 1.8ms preprocess, 40.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.2ms
# Speed: 1.8ms preprocess, 38.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.8ms
# Speed: 1.9ms preprocess, 37.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.2ms
# Speed: 1.8ms preprocess, 37.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 1.7ms preprocess, 38.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.3ms
# Speed: 1.8ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 41.8ms
# Speed: 1.7ms preprocess, 41.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.6ms
# Speed: 1.5ms preprocess, 38.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.6ms
# Speed: 1.7ms preprocess, 38.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.6ms
# Speed: 1.7ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 36.4ms
# Speed: 1.6ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.6ms
# Speed: 1.4ms preprocess, 37.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 39.9ms
# Speed: 1.4ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.3ms
# Speed: 1.5ms preprocess, 40.3ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 39.1ms
# Speed: 1.5ms preprocess, 39.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.5ms
# Speed: 1.5ms preprocess, 40.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.0ms
# Speed: 1.7ms preprocess, 40.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 1.5ms preprocess, 38.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.9ms
# Speed: 1.9ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.8ms
# Speed: 1.7ms preprocess, 38.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.9ms
# Speed: 1.6ms preprocess, 38.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 39.3ms
# Speed: 1.5ms preprocess, 39.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 40.6ms
# Speed: 1.8ms preprocess, 40.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 37.9ms
# Speed: 1.7ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.5ms
# Speed: 1.8ms preprocess, 38.5ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.4ms
# Speed: 2.2ms preprocess, 38.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 38.0ms
# Speed: 1.5ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
#
# 0: 384x640 (no detections), 39.1ms
# Speed: 1.6ms preprocess, 39.1ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Detected classes: {0: '-', 1: 'Black Panther', 2: 'Cheetah', 3: 'Elephant', 4: 'Fox', 5: 'Golden_Cat', 6: 'Human', 7: 'Hyena', 8: 'Leopard', 9: 'Lion', 10: 'Nothing Found', 11: 'Rhino', 12: 'Squirrel', 13: 'Tiger', 14: 'Wolf', 15: 'bird', 16: 'buffalo', 17: 'deer', 18: 'dog', 19: 'giraffe', 20: 'kangroo', 21: 'spider', 22: 'zebra'}
